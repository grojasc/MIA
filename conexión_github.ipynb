# %% [markdown]
# <a href="https://colab.research.google.com/github/grojasc/MIA/blob/main/conexi%C3%B3n_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q xlrd
# !git clone https://github.com/grojasc/MIA_DS_project
# Out:
# Cloning into 'MIA_DS_project'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 182 (delta 19), reused 0 (delta 0), pack-reused 150
# Receiving objects: 100% (182/182), 14.99 MiB | 20.80 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# !ls ./MIA_DS_project/Data/
# Out:
#  articles-16585_SD_001.xlsx
#  cr2_qflxDaily_2018_description.txt
#  cr2_qflxDaily_2018_stations.txt
# 'Crecimiento Mundial.xlsx'
# 'Crecimiento Población Mundial.xlsx'
#  Cuadro_19052022140129.xlsx
#  desktop.ini
#  estimaciones-y-proyecciones-2002-2035-comunas.xlsx
#  IPG2014_v1.CPG
#  poblacion_comuna.csv
#  poblacion_region.csv

# %%
import pandas as pd
df = pd.read_csv('MIA_DS_project/Data/poblacion_comuna.csv', encoding = 'latin1')
df
# Out:
#      Unnamed: 0  region nombre_region  comuna  nombre_comuna  p_2002  p_2003  \
# 0             1       1      Tarapacá    1101        Iquique  173611  169002
# 1             2       1      Tarapacá    1107  Alto Hospicio   53625   63806
# 2             3       1      Tarapacá    1401   Pozo Almonte    9833    9837
# 3             4       1      Tarapacá    1402         Camiña    1325    1271
# 4             5       1      Tarapacá    1403       Colchane    1636    1564
# ..          ...     ...           ...     ...            ...     ...     ...
# 341         342      16         Ñuble   16301     San Carlos   52108   52109
# 342         343      16         Ñuble   16302       Coihueco   24538   24854
# 343         344      16         Ñuble   16303         Ñiquén   11876   11795
# 344         345      16         Ñuble   16304     San Fabián    3700    3761
# 345         346      16         Ñuble   16305    San Nicolás   10017   10170
#
# ...

# %%
# Out:
#   File "<ipython-input-1-0a8eeaf85e07>", line 1
#     $$ h
#     ^
# SyntaxError: invalid syntax
